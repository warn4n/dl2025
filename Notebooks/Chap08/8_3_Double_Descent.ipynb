# %% [markdown]
# <a href="https://colab.research.google.com/github/warn4n/dl2025/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-qfd783ec
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-qfd783ec
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14663 sha256=1fbce4156920872af8dd965b72523c5095d311cecabf8f5c59f47eef57c25eee
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p90gjr73/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.247748, train error 85.53,  test loss 2.239028, test error 85.22
# Epoch   100, train loss 1.915101, train error 71.15,  test loss 1.753474, test error 68.82
# Epoch   200, train loss 1.910425, train error 72.15,  test loss 1.733384, test error 69.93
# Epoch   300, train loss 1.902112, train error 71.25,  test loss 1.735671, test error 67.97
# Epoch   400, train loss 1.897137, train error 70.85,  test loss 1.739760, test error 68.97
# Epoch   500, train loss 1.897899, train error 70.65,  test loss 1.747622, test error 68.72
# Epoch   600, train loss 1.900172, train error 70.68,  test loss 1.738510, test error 67.53
# Epoch   700, train loss 1.894321, train error 69.97,  test loss 1.738720, test error 68.70
# Epoch   800, train loss 1.895631, train error 70.95,  test loss 1.750906, test error 69.32
# Epoch   900, train loss 1.899199, train error 71.28,  test loss 1.722862, test error 69.07
# Training model with   4 hidden variables
# Epoch     0, train loss 2.281018, train error 86.65,  test loss 2.281957, test error 86.62
# Epoch   100, train loss 1.797874, train error 66.45,  test loss 1.651336, test error 64.32
# Epoch   200, train loss 1.769916, train error 64.65,  test loss 1.609398, test error 62.92
# Epoch   300, train loss 1.771331, train error 64.43,  test loss 1.619868, test error 62.97
# Epoch   400, train loss 1.759356, train error 64.62,  test loss 1.617234, test error 63.58
# Epoch   500, train loss 1.758098, train error 63.97,  test loss 1.605296, test error 62.60
# Epoch   600, train loss 1.758293, train error 64.15,  test loss 1.612555, test error 62.92
# Epoch   700, train loss 1.761025, train error 64.28,  test loss 1.623865, test error 63.33
# Epoch   800, train loss 1.755013, train error 63.67,  test loss 1.618583, test error 63.33
# Epoch   900, train loss 1.751120, train error 64.10,  test loss 1.609111, test error 63.08
# Training model with   6 hidden variables
# Epoch     0, train loss 2.299877, train error 88.45,  test loss 2.303139, test error 88.05
# Epoch   100, train loss 1.666727, train error 59.58,  test loss 1.484273, test error 57.10
# Epoch   200, train loss 1.621444, train error 57.22,  test loss 1.435261, test error 53.90
# Epoch   300, train loss 1.613821, train error 57.08,  test loss 1.427623, test error 53.67
# Epoch   400, train loss 1.613561, train error 57.40,  test loss 1.428025, test error 54.47
# Epoch   500, train loss 1.608873, train error 56.25,  test loss 1.430726, test error 54.33
# Epoch   600, train loss 1.607312, train error 56.12,  test loss 1.429908, test error 53.90
# Epoch   700, train loss 1.608640, train error 56.50,  test loss 1.429074, test error 54.38
# Epoch   800, train loss 1.609137, train error 56.53,  test loss 1.431494, test error 54.42
# Epoch   900, train loss 1.605454, train error 56.10,  test loss 1.439622, test error 54.38
# Training model with   8 hidden variables
# Epoch     0, train loss 2.250628, train error 84.88,  test loss 2.236931, test error 83.62
# Epoch   100, train loss 1.616483, train error 57.25,  test loss 1.464579, test error 56.80
# Epoch   200, train loss 1.573882, train error 55.42,  test loss 1.461687, test error 56.83
# Epoch   300, train loss 1.549673, train error 54.62,  test loss 1.450636, test error 55.62
# Epoch   400, train loss 1.536084, train error 54.62,  test loss 1.454677, test error 55.25
# Epoch   500, train loss 1.529889, train error 54.03,  test loss 1.472496, test error 55.92
# Epoch   600, train loss 1.522684, train error 53.22,  test loss 1.463478, test error 55.72
# Epoch   700, train loss 1.523922, train error 53.30,  test loss 1.464586, test error 56.65
# Epoch   800, train loss 1.519607, train error 53.20,  test loss 1.454057, test error 55.50
# Epoch   900, train loss 1.524839, train error 54.12,  test loss 1.468133, test error 55.47
# Training model with  10 hidden variables
# Epoch     0, train loss 2.287642, train error 87.40,  test loss 2.293047, test error 88.60
# Epoch   100, train loss 1.471428, train error 50.15,  test loss 1.335762, test error 49.62
# Epoch   200, train loss 1.426591, train error 48.38,  test loss 1.300521, test error 48.78
# Epoch   300, train loss 1.403479, train error 47.08,  test loss 1.295564, test error 48.28
# Epoch   400, train loss 1.398278, train error 47.25,  test loss 1.308801, test error 48.97
# Epoch   500, train loss 1.380860, train error 46.00,  test loss 1.289165, test error 48.70
# Epoch   600, train loss 1.377706, train error 45.90,  test loss 1.282234, test error 47.62
# Epoch   700, train loss 1.377754, train error 46.78,  test loss 1.303142, test error 48.70
# Epoch   800, train loss 1.364536, train error 46.88,  test loss 1.304110, test error 47.97
# Epoch   900, train loss 1.361572, train error 46.15,  test loss 1.311538, test error 47.47
# Training model with  14 hidden variables
# Epoch     0, train loss 2.227379, train error 82.65,  test loss 2.201416, test error 82.18
# Epoch   100, train loss 1.411179, train error 47.85,  test loss 1.338400, test error 49.33
# Epoch   200, train loss 1.343570, train error 45.25,  test loss 1.337425, test error 49.17
# Epoch   300, train loss 1.309310, train error 43.83,  test loss 1.359558, test error 49.62
# Epoch   400, train loss 1.289743, train error 42.92,  test loss 1.364548, test error 49.60
# Epoch   500, train loss 1.279526, train error 42.85,  test loss 1.390375, test error 50.53
# Epoch   600, train loss 1.272097, train error 42.83,  test loss 1.406351, test error 51.60
# Epoch   700, train loss 1.256701, train error 41.97,  test loss 1.402645, test error 51.08
# Epoch   800, train loss 1.256474, train error 42.47,  test loss 1.424520, test error 51.25
# Epoch   900, train loss 1.250375, train error 41.62,  test loss 1.422763, test error 50.65
# Training model with  18 hidden variables
# Epoch     0, train loss 2.200052, train error 79.43,  test loss 2.213631, test error 81.12
# Epoch   100, train loss 1.368731, train error 46.28,  test loss 1.345014, test error 50.80
# Epoch   200, train loss 1.267800, train error 43.33,  test loss 1.320583, test error 48.65
# Epoch   300, train loss 1.195462, train error 40.10,  test loss 1.362069, test error 49.05
# Epoch   400, train loss 1.167098, train error 39.92,  test loss 1.414298, test error 50.05
# Epoch   500, train loss 1.154865, train error 40.15,  test loss 1.452910, test error 51.45
# Epoch   600, train loss 1.149151, train error 40.67,  test loss 1.473126, test error 50.17
# Epoch   700, train loss 1.131350, train error 39.92,  test loss 1.509129, test error 51.67
# Epoch   800, train loss 1.129569, train error 39.97,  test loss 1.521658, test error 51.50
# Epoch   900, train loss 1.113958, train error 39.67,  test loss 1.532291, test error 50.90
# Training model with  22 hidden variables
# Epoch     0, train loss 2.163632, train error 79.85,  test loss 2.128318, test error 78.65
# Epoch   100, train loss 1.276199, train error 43.00,  test loss 1.305429, test error 49.53
# Epoch   200, train loss 1.148574, train error 38.33,  test loss 1.361449, test error 49.38
# Epoch   300, train loss 1.089649, train error 36.50,  test loss 1.429098, test error 49.83
# Epoch   400, train loss 1.055145, train error 35.62,  test loss 1.493734, test error 50.72
# Epoch   500, train loss 1.031398, train error 35.12,  test loss 1.558491, test error 51.55
# Epoch   600, train loss 1.018477, train error 34.40,  test loss 1.631086, test error 51.95
# Epoch   700, train loss 1.012934, train error 34.32,  test loss 1.674347, test error 52.20
# Epoch   800, train loss 1.002808, train error 34.07,  test loss 1.714111, test error 52.45
# Epoch   900, train loss 0.993532, train error 33.68,  test loss 1.724838, test error 52.15
# Training model with  26 hidden variables
# Epoch     0, train loss 2.123436, train error 77.60,  test loss 2.096799, test error 77.28
# Epoch   100, train loss 1.161674, train error 39.25,  test loss 1.303151, test error 47.70
# Epoch   200, train loss 1.023986, train error 34.35,  test loss 1.397007, test error 49.53
# Epoch   300, train loss 0.974125, train error 32.85,  test loss 1.516487, test error 51.05
# Epoch   400, train loss 0.939772, train error 32.30,  test loss 1.644472, test error 52.25
# Epoch   500, train loss 0.902184, train error 30.72,  test loss 1.718609, test error 52.60
# Epoch   600, train loss 0.868413, train error 30.15,  test loss 1.805360, test error 53.50
# Epoch   700, train loss 0.850674, train error 29.32,  test loss 1.890853, test error 53.47
# Epoch   800, train loss 0.828032, train error 28.20,  test loss 1.972136, test error 54.08
# Epoch   900, train loss 0.820410, train error 28.70,  test loss 2.004774, test error 53.62
# Training model with  30 hidden variables
# Epoch     0, train loss 2.113930, train error 77.78,  test loss 2.071336, test error 77.35
# Epoch   100, train loss 1.105133, train error 36.38,  test loss 1.336111, test error 48.97
# Epoch   200, train loss 0.921279, train error 30.38,  test loss 1.511106, test error 50.42
# Epoch   300, train loss 0.822425, train error 26.97,  test loss 1.734267, test error 52.33
# Epoch   400, train loss 0.775324, train error 26.07,  test loss 1.918474, test error 53.15
# Epoch   500, train loss 0.735631, train error 24.55,  test loss 2.108508, test error 53.20
# Epoch   600, train loss 0.719674, train error 24.28,  test loss 2.262783, test error 53.22
# Epoch   700, train loss 0.679625, train error 22.90,  test loss 2.391844, test error 53.60
# Epoch   800, train loss 0.671354, train error 23.35,  test loss 2.533513, test error 53.70
# Epoch   900, train loss 0.664449, train error 22.78,  test loss 2.622488, test error 53.72
# Training model with  35 hidden variables
# Epoch     0, train loss 2.063540, train error 76.95,  test loss 2.022745, test error 78.00
# Epoch   100, train loss 1.019797, train error 32.45,  test loss 1.370843, test error 48.22
# Epoch   200, train loss 0.800439, train error 25.72,  test loss 1.628323, test error 49.90
# Epoch   300, train loss 0.684606, train error 22.10,  test loss 1.995353, test error 52.97
# Epoch   400, train loss 0.592108, train error 19.28,  test loss 2.290672, test error 53.05
# Epoch   500, train loss 0.558300, train error 17.85,  test loss 2.615115, test error 54.30
# Epoch   600, train loss 0.531939, train error 17.22,  test loss 2.921253, test error 54.17
# Epoch   700, train loss 0.488122, train error 16.35,  test loss 3.263344, test error 54.92
# Epoch   800, train loss 0.436776, train error 14.10,  test loss 3.450205, test error 55.58
# Epoch   900, train loss 0.439884, train error 14.78,  test loss 3.730695, test error 55.08
# Training model with  40 hidden variables
# Epoch     0, train loss 2.082258, train error 76.85,  test loss 2.055310, test error 78.20
# Epoch   100, train loss 0.894531, train error 28.85,  test loss 1.462314, test error 49.78
# Epoch   200, train loss 0.641355, train error 20.95,  test loss 1.911617, test error 52.10
# Epoch   300, train loss 0.500596, train error 15.75,  test loss 2.445609, test error 53.05
# Epoch   400, train loss 0.448598, train error 14.75,  test loss 2.992204, test error 53.60
# Epoch   500, train loss 0.359358, train error 11.88,  test loss 3.579614, test error 54.35
# Epoch   600, train loss 0.371750, train error 12.68,  test loss 4.327323, test error 55.25
# Epoch   700, train loss 0.260962, train error 8.15,  test loss 4.795235, test error 54.72
# Epoch   800, train loss 0.236925, train error 8.30,  test loss 5.444940, test error 54.92
# Epoch   900, train loss 0.243014, train error 8.72,  test loss 6.163250, test error 55.22
# Training model with  45 hidden variables
# Epoch     0, train loss 2.085582, train error 78.03,  test loss 2.047856, test error 76.97
# Epoch   100, train loss 0.827216, train error 27.03,  test loss 1.475142, test error 50.08
# Epoch   200, train loss 0.524475, train error 16.80,  test loss 2.219491, test error 54.50
# Epoch   300, train loss 0.345442, train error 11.70,  test loss 3.077555, test error 54.92
# Epoch   400, train loss 0.248195, train error 7.72,  test loss 4.189416, test error 55.72
# Epoch   500, train loss 0.185414, train error 6.40,  test loss 5.281665, test error 56.35
# Epoch   600, train loss 0.149122, train error 5.05,  test loss 6.440078, test error 57.20
# Epoch   700, train loss 0.021994, train error 0.03,  test loss 7.758798, test error 57.17
# Epoch   800, train loss 0.012794, train error 0.00,  test loss 8.660468, test error 57.22
# Epoch   900, train loss 0.009055, train error 0.00,  test loss 9.324828, test error 57.28
# Training model with  50 hidden variables
# Epoch     0, train loss 2.069778, train error 76.57,  test loss 1.992861, test error 75.15
# Epoch   100, train loss 0.687370, train error 21.75,  test loss 1.582555, test error 50.25
# Epoch   200, train loss 0.332838, train error 9.47,  test loss 2.651103, test error 53.47
# Epoch   300, train loss 0.149776, train error 3.75,  test loss 4.277379, test error 55.83
# Epoch   400, train loss 0.027359, train error 0.00,  test loss 5.891410, test error 56.83
# Epoch   500, train loss 0.012954, train error 0.00,  test loss 6.821877, test error 56.60
# Epoch   600, train loss 0.008104, train error 0.00,  test loss 7.447751, test error 56.90
# Epoch   700, train loss 0.005835, train error 0.00,  test loss 7.916924, test error 56.72
# Epoch   800, train loss 0.004537, train error 0.00,  test loss 8.301328, test error 56.92
# Epoch   900, train loss 0.003652, train error 0.00,  test loss 8.608509, test error 56.85
# Training model with  55 hidden variables
# Epoch     0, train loss 2.096806, train error 76.78,  test loss 2.055206, test error 76.95
# Epoch   100, train loss 0.616268, train error 19.10,  test loss 1.618338, test error 51.35
# Epoch   200, train loss 0.215825, train error 4.95,  test loss 2.888534, test error 54.30
# Epoch   300, train loss 0.047168, train error 0.07,  test loss 4.520727, test error 54.83
# Epoch   400, train loss 0.015331, train error 0.00,  test loss 5.549049, test error 55.30
# Epoch   500, train loss 0.008912, train error 0.00,  test loss 6.179795, test error 55.20
# Epoch   600, train loss 0.006009, train error 0.00,  test loss 6.620163, test error 55.10
# Epoch   700, train loss 0.004474, train error 0.00,  test loss 6.967481, test error 55.12
# Epoch   800, train loss 0.003530, train error 0.00,  test loss 7.245847, test error 55.22
# Epoch   900, train loss 0.002882, train error 0.00,  test loss 7.485376, test error 55.10
# Training model with  60 hidden variables
# Epoch     0, train loss 2.058159, train error 77.32,  test loss 1.972992, test error 76.35
# Epoch   100, train loss 0.573924, train error 17.43,  test loss 1.736030, test error 51.80
# Epoch   200, train loss 0.110679, train error 1.15,  test loss 3.334638, test error 53.33
# Epoch   300, train loss 0.019472, train error 0.00,  test loss 4.741174, test error 54.15
# Epoch   400, train loss 0.009388, train error 0.00,  test loss 5.441972, test error 54.62
# Epoch   500, train loss 0.005941, train error 0.00,  test loss 5.903119, test error 54.40
# Epoch   600, train loss 0.004245, train error 0.00,  test loss 6.247134, test error 54.65
# Epoch   700, train loss 0.003256, train error 0.00,  test loss 6.512093, test error 54.65
# Epoch   800, train loss 0.002619, train error 0.00,  test loss 6.737952, test error 54.60
# Epoch   900, train loss 0.002173, train error 0.00,  test loss 6.927164, test error 54.65
# Training model with  70 hidden variables
# Epoch     0, train loss 2.020712, train error 77.57,  test loss 1.956176, test error 76.97
# Epoch   100, train loss 0.375488, train error 9.18,  test loss 1.893382, test error 50.60
# Epoch   200, train loss 0.035895, train error 0.00,  test loss 3.525751, test error 53.03
# Epoch   300, train loss 0.011323, train error 0.00,  test loss 4.346696, test error 53.50
# Epoch   400, train loss 0.006267, train error 0.00,  test loss 4.790647, test error 53.33
# Epoch   500, train loss 0.004200, train error 0.00,  test loss 5.102489, test error 53.42
# Epoch   600, train loss 0.003107, train error 0.00,  test loss 5.337968, test error 53.58
# Epoch   700, train loss 0.002435, train error 0.00,  test loss 5.530131, test error 53.42
# Epoch   800, train loss 0.001989, train error 0.00,  test loss 5.692957, test error 53.62
# Epoch   900, train loss 0.001669, train error 0.00,  test loss 5.829094, test error 53.50
# Training model with  80 hidden variables
# Epoch     0, train loss 2.019661, train error 74.18,  test loss 1.970634, test error 75.22
# Epoch   100, train loss 0.219229, train error 3.68,  test loss 2.122711, test error 51.17
# Epoch   200, train loss 0.019927, train error 0.00,  test loss 3.410286, test error 51.17
# Epoch   300, train loss 0.008087, train error 0.00,  test loss 3.948410, test error 51.10
# Epoch   400, train loss 0.004839, train error 0.00,  test loss 4.272465, test error 51.08
# Epoch   500, train loss 0.003336, train error 0.00,  test loss 4.504628, test error 51.40
# Epoch   600, train loss 0.002516, train error 0.00,  test loss 4.683867, test error 51.45
# Epoch   700, train loss 0.001999, train error 0.00,  test loss 4.830365, test error 51.40
# Epoch   800, train loss 0.001644, train error 0.00,  test loss 4.952384, test error 51.33
# Epoch   900, train loss 0.001392, train error 0.00,  test loss 5.059128, test error 51.40
# Training model with  90 hidden variables
# Epoch     0, train loss 1.997860, train error 74.50,  test loss 1.937059, test error 73.32
# Epoch   100, train loss 0.154073, train error 1.47,  test loss 2.126301, test error 50.72
# Epoch   200, train loss 0.014935, train error 0.00,  test loss 3.221162, test error 51.78
# Epoch   300, train loss 0.006544, train error 0.00,  test loss 3.651325, test error 51.72
# Epoch   400, train loss 0.003981, train error 0.00,  test loss 3.918441, test error 51.50
# Epoch   500, train loss 0.002799, train error 0.00,  test loss 4.106576, test error 51.55
# Epoch   600, train loss 0.002128, train error 0.00,  test loss 4.254580, test error 51.60
# Epoch   700, train loss 0.001699, train error 0.00,  test loss 4.376338, test error 51.58
# Epoch   800, train loss 0.001406, train error 0.00,  test loss 4.478463, test error 51.67
# Epoch   900, train loss 0.001194, train error 0.00,  test loss 4.566835, test error 51.62
# Training model with 100 hidden variables
# Epoch     0, train loss 2.002800, train error 74.18,  test loss 1.906944, test error 73.00
# Epoch   100, train loss 0.094581, train error 0.22,  test loss 2.148240, test error 49.85
# Epoch   200, train loss 0.012334, train error 0.00,  test loss 2.975131, test error 49.78
# Epoch   300, train loss 0.005728, train error 0.00,  test loss 3.325604, test error 50.17
# Epoch   400, train loss 0.003580, train error 0.00,  test loss 3.547071, test error 49.95
# Epoch   500, train loss 0.002539, train error 0.00,  test loss 3.704788, test error 50.03
# Epoch   600, train loss 0.001943, train error 0.00,  test loss 3.833704, test error 50.15
# Epoch   700, train loss 0.001560, train error 0.00,  test loss 3.938565, test error 50.05
# Epoch   800, train loss 0.001296, train error 0.00,  test loss 4.025879, test error 50.08
# Epoch   900, train loss 0.001103, train error 0.00,  test loss 4.102197, test error 49.97
# Training model with 120 hidden variables
# Epoch     0, train loss 1.978531, train error 72.53,  test loss 1.923785, test error 73.82
# Epoch   100, train loss 0.051715, train error 0.00,  test loss 2.170169, test error 49.75
# Epoch   200, train loss 0.009614, train error 0.00,  test loss 2.786345, test error 50.25
# Epoch   300, train loss 0.004734, train error 0.00,  test loss 3.064125, test error 50.40
# Epoch   400, train loss 0.003023, train error 0.00,  test loss 3.243207, test error 50.55
# Epoch   500, train loss 0.002175, train error 0.00,  test loss 3.374093, test error 50.72
# Epoch   600, train loss 0.001679, train error 0.00,  test loss 3.478817, test error 50.55
# Epoch   700, train loss 0.001356, train error 0.00,  test loss 3.564392, test error 50.60
# Epoch   800, train loss 0.001132, train error 0.00,  test loss 3.636928, test error 50.60
# Epoch   900, train loss 0.000967, train error 0.00,  test loss 3.700160, test error 50.70
# Training model with 140 hidden variables
# Epoch     0, train loss 1.962103, train error 72.18,  test loss 1.878008, test error 72.60
# Epoch   100, train loss 0.035812, train error 0.00,  test loss 2.188366, test error 50.42
# Epoch   200, train loss 0.008121, train error 0.00,  test loss 2.683210, test error 50.33
# Epoch   300, train loss 0.004149, train error 0.00,  test loss 2.921818, test error 50.35
# Epoch   400, train loss 0.002699, train error 0.00,  test loss 3.076603, test error 50.25
# Epoch   500, train loss 0.001964, train error 0.00,  test loss 3.191808, test error 50.40
# Epoch   600, train loss 0.001526, train error 0.00,  test loss 3.283793, test error 50.58
# Epoch   700, train loss 0.001240, train error 0.00,  test loss 3.359467, test error 50.58
# Epoch   800, train loss 0.001038, train error 0.00,  test loss 3.424570, test error 50.53
# Epoch   900, train loss 0.000889, train error 0.00,  test loss 3.481141, test error 50.42
# Training model with 160 hidden variables
# Epoch     0, train loss 1.930389, train error 70.82,  test loss 1.855646, test error 72.55
# Epoch   100, train loss 0.028222, train error 0.00,  test loss 2.108977, test error 48.85
# Epoch   200, train loss 0.007176, train error 0.00,  test loss 2.513848, test error 48.65
# Epoch   300, train loss 0.003796, train error 0.00,  test loss 2.716522, test error 48.70
# Epoch   400, train loss 0.002501, train error 0.00,  test loss 2.851175, test error 49.00
# Epoch   500, train loss 0.001835, train error 0.00,  test loss 2.951625, test error 48.92
# Epoch   600, train loss 0.001434, train error 0.00,  test loss 3.031906, test error 48.95
# Epoch   700, train loss 0.001170, train error 0.00,  test loss 3.098340, test error 49.00
# Epoch   800, train loss 0.000982, train error 0.00,  test loss 3.154833, test error 48.95
# Epoch   900, train loss 0.000844, train error 0.00,  test loss 3.204483, test error 48.85
# Training model with 180 hidden variables
# Epoch     0, train loss 1.922071, train error 70.53,  test loss 1.841471, test error 71.18
# Epoch   100, train loss 0.023877, train error 0.00,  test loss 2.031221, test error 48.50
# Epoch   200, train loss 0.006468, train error 0.00,  test loss 2.372113, test error 48.55
# Epoch   300, train loss 0.003471, train error 0.00,  test loss 2.547746, test error 48.47
# Epoch   400, train loss 0.002304, train error 0.00,  test loss 2.665017, test error 48.45
# Epoch   500, train loss 0.001696, train error 0.00,  test loss 2.752700, test error 48.50
# Epoch   600, train loss 0.001329, train error 0.00,  test loss 2.823226, test error 48.45
# Epoch   700, train loss 0.001086, train error 0.00,  test loss 2.882042, test error 48.40
# Epoch   800, train loss 0.000913, train error 0.00,  test loss 2.932360, test error 48.35
# Epoch   900, train loss 0.000785, train error 0.00,  test loss 2.976716, test error 48.38
# Training model with 200 hidden variables
# Epoch     0, train loss 1.920906, train error 70.22,  test loss 1.845555, test error 72.40
# Epoch   100, train loss 0.021502, train error 0.00,  test loss 2.026455, test error 48.75
# Epoch   200, train loss 0.006100, train error 0.00,  test loss 2.339148, test error 48.53
# Epoch   300, train loss 0.003313, train error 0.00,  test loss 2.496631, test error 48.53
# Epoch   400, train loss 0.002211, train error 0.00,  test loss 2.604214, test error 48.30
# Epoch   500, train loss 0.001634, train error 0.00,  test loss 2.686415, test error 48.28
# Epoch   600, train loss 0.001283, train error 0.00,  test loss 2.751191, test error 48.40
# Epoch   700, train loss 0.001049, train error 0.00,  test loss 2.805479, test error 48.40
# Epoch   800, train loss 0.000883, train error 0.00,  test loss 2.852200, test error 48.42
# Epoch   900, train loss 0.000760, train error 0.00,  test loss 2.893026, test error 48.47
# Training model with 250 hidden variables
# Epoch     0, train loss 1.909168, train error 69.30,  test loss 1.841934, test error 70.60
# Epoch   100, train loss 0.017044, train error 0.00,  test loss 1.913858, test error 47.05
# Epoch   200, train loss 0.005368, train error 0.00,  test loss 2.168465, test error 47.10
# Epoch   300, train loss 0.002988, train error 0.00,  test loss 2.302569, test error 47.20
# Epoch   400, train loss 0.002013, train error 0.00,  test loss 2.393270, test error 47.12
# Epoch   500, train loss 0.001498, train error 0.00,  test loss 2.463185, test error 47.12
# Epoch   600, train loss 0.001182, train error 0.00,  test loss 2.519196, test error 47.15
# Epoch   700, train loss 0.000971, train error 0.00,  test loss 2.566213, test error 47.12
# Epoch   800, train loss 0.000820, train error 0.00,  test loss 2.606732, test error 47.10
# Epoch   900, train loss 0.000708, train error 0.00,  test loss 2.641783, test error 47.08
# Training model with 300 hidden variables
# Epoch     0, train loss 1.893288, train error 68.80,  test loss 1.809269, test error 69.75
# Epoch   100, train loss 0.014732, train error 0.00,  test loss 1.890707, test error 47.05
# Epoch   200, train loss 0.004853, train error 0.00,  test loss 2.119179, test error 46.80
# Epoch   300, train loss 0.002743, train error 0.00,  test loss 2.242858, test error 46.78
# Epoch   400, train loss 0.001866, train error 0.00,  test loss 2.329452, test error 46.78
# Epoch   500, train loss 0.001396, train error 0.00,  test loss 2.393946, test error 46.90
# Epoch   600, train loss 0.001105, train error 0.00,  test loss 2.446535, test error 47.00
# Epoch   700, train loss 0.000909, train error 0.00,  test loss 2.490690, test error 46.90
# Epoch   800, train loss 0.000769, train error 0.00,  test loss 2.529431, test error 46.83
# Epoch   900, train loss 0.000664, train error 0.00,  test loss 2.562784, test error 46.83
# Training model with 400 hidden variables
# Epoch     0, train loss 1.809171, train error 63.72,  test loss 1.754552, test error 69.32
# Epoch   100, train loss 0.011444, train error 0.00,  test loss 1.762284, test error 46.12
# Epoch   200, train loss 0.004130, train error 0.00,  test loss 1.938042, test error 45.92
# Epoch   300, train loss 0.002394, train error 0.00,  test loss 2.035312, test error 45.80
# Epoch   400, train loss 0.001651, train error 0.00,  test loss 2.103315, test error 45.85
# Epoch   500, train loss 0.001245, train error 0.00,  test loss 2.154697, test error 45.95
# Epoch   600, train loss 0.000992, train error 0.00,  test loss 2.196285, test error 45.85
# Epoch   700, train loss 0.000820, train error 0.00,  test loss 2.231455, test error 45.78
# Epoch   800, train loss 0.000696, train error 0.00,  test loss 2.261997, test error 45.72
# Epoch   900, train loss 0.000603, train error 0.00,  test loss 2.289373, test error 45.70

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
